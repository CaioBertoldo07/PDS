# %% [markdown]
# # Trabalho final PDS
# ## Aluno: Caio Bertoldo
# ### Curso: Engenharia da Computação

# %% [markdown]
# # Trabalho Unificado: Análise de Qualidade de Áudio e Vídeo com Filtros FIR/IIR e Métricas de Avaliação

# %%
# Importações
import numpy as np 
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal
import scipy.io.wavfile as wav
from skimage import io, color, metrics
import cv2  
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 import scipy.signal as signal
#       6 import scipy.io.wavfile as wav
# ----> 7 from skimage import io, color, metrics
#       8 import cv2
#       9 import os
#
# ModuleNotFoundError: No module named 'skimage'
